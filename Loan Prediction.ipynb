# %%
pwd
# Out:
# '/home/sanjeet'

# %%
cd /home/sanjeet/Downloads
# Out:
# /home/sanjeet/Downloads

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("test.csv")
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001015    Male     Yes          0      Graduate            No
# 1    LP001022    Male     Yes          1      Graduate            No
# 2    LP001031    Male     Yes          2      Graduate            No
# 3    LP001035    Male     Yes          2      Graduate            No
# 4    LP001051    Male      No          0  Not Graduate            No
# 5    LP001054    Male     Yes          0  Not Graduate           Yes
# 6    LP001055  Female      No          1  Not Graduate            No
# 7    LP001056    Male     Yes          2  Not Graduate            No
# 8    LP001059    Male     Yes          2      Graduate           NaN
# 9    LP001067    Male      No          0  Not Graduate            No
# 10   LP001078    Male      No          0  Not Graduate            No
# 11   LP001082    Male     Yes          1      Graduate           NaN
# 12   LP001083    Male      No         3+      Graduate            No
# ...

# %%
print(df.groupby['Property_area'].unique())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-02309ce7d3d9> in <module>()
# ----> 1 print(df.groupby['Property_area'].unique())
#
# TypeError: 'method' object is not subscriptable

# %%
print(df.groupby['Property_Area'].unique())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-969fd4b764f8> in <module>()
# ----> 1 print(df.groupby['Property_Area'].unique())
#
# TypeError: 'method' object is not subscriptable

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001015    Male     Yes          0      Graduate            No
# 1    LP001022    Male     Yes          1      Graduate            No
# 2    LP001031    Male     Yes          2      Graduate            No
# 3    LP001035    Male     Yes          2      Graduate            No
# 4    LP001051    Male      No          0  Not Graduate            No
# 5    LP001054    Male     Yes          0  Not Graduate           Yes
# 6    LP001055  Female      No          1  Not Graduate            No
# 7    LP001056    Male     Yes          2  Not Graduate            No
# 8    LP001059    Male     Yes          2      Graduate           NaN
# 9    LP001067    Male      No          0  Not Graduate            No
# 10   LP001078    Male      No          0  Not Graduate            No
# 11   LP001082    Male     Yes          1      Graduate           NaN
# 12   LP001083    Male      No         3+      Graduate            No
# ...

# %%
print(df.groupby['Property_area'].size())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-a6f38fc8d085> in <module>()
# ----> 1 print(df.groupby['Property_area'].size())
#
# TypeError: 'method' object is not subscriptable

# %%
print(df.groupby('Property_Area').size())
# Out:
# Property_Area
# Rural        111
# Semiurban    116
# Urban        140
# dtype: int64

# %%
import seaborn as sns
sns.countplot(df['Property_Area'],label="Count")
plt.show()

# %%
print(df.groupby('Dependents').size())
# Out:
# Dependents
# 0     200
# 1      58
# 2      59
# 3+     40
# dtype: int64

# %%
import seaborn as sns
sns.countplot(df['Dependents'],label="Count")
plt.show()

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001015    Male     Yes          0      Graduate            No
# 1    LP001022    Male     Yes          1      Graduate            No
# 2    LP001031    Male     Yes          2      Graduate            No
# 3    LP001035    Male     Yes          2      Graduate            No
# 4    LP001051    Male      No          0  Not Graduate            No
# 5    LP001054    Male     Yes          0  Not Graduate           Yes
# 6    LP001055  Female      No          1  Not Graduate            No
# 7    LP001056    Male     Yes          2  Not Graduate            No
# 8    LP001059    Male     Yes          2      Graduate           NaN
# 9    LP001067    Male      No          0  Not Graduate            No
# 10   LP001078    Male      No          0  Not Graduate            No
# 11   LP001082    Male     Yes          1      Graduate           NaN
# 12   LP001083    Male      No         3+      Graduate            No
# ...

# %%
print(df.groupby('Gender').size())
# Out:
# Gender
# Female     70
# Male      286
# dtype: int64

# %%
import seaborn as sns
sns.countplot(df['Gender'],label="Count")
plt.show()

# %%
print(df.groupby('Married').size())
# Out:
# Married
# No     134
# Yes    233
# dtype: int64

# %%
import seaborn as sns
sns.countplot(df['Married'],label="Count")
plt.show()

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001015    Male     Yes          0      Graduate            No
# 1    LP001022    Male     Yes          1      Graduate            No
# 2    LP001031    Male     Yes          2      Graduate            No
# 3    LP001035    Male     Yes          2      Graduate            No
# 4    LP001051    Male      No          0  Not Graduate            No
# 5    LP001054    Male     Yes          0  Not Graduate           Yes
# 6    LP001055  Female      No          1  Not Graduate            No
# 7    LP001056    Male     Yes          2  Not Graduate            No
# 8    LP001059    Male     Yes          2      Graduate           NaN
# 9    LP001067    Male      No          0  Not Graduate            No
# 10   LP001078    Male      No          0  Not Graduate            No
# 11   LP001082    Male     Yes          1      Graduate           NaN
# 12   LP001083    Male      No         3+      Graduate            No
# ...

# %%
print(df.groupby('Education').size())
# Out:
# Education
# Graduate        283
# Not Graduate     84
# dtype: int64

# %%
import seaborn as sns
sns.pie(df['Education'],label="Count")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-19eb5461003c> in <module>()
#       1 import seaborn as sns
# ----> 2 sns.pie(df['Education'],label="Count")
#       3 plt.show()
#
# AttributeError: module 'seaborn' has no attribute 'pie'

# %%
import seaborn as sns
sns.countplot(df['Education'],label="Count")
plt.show()

# %%
print(df.groupby('Loan_Amount_Term').size())
# Out:
# Loan_Amount_Term
# 6.0        1
# 12.0       1
# 36.0       1
# 60.0       1
# 84.0       3
# 120.0      1
# 180.0     22
# 240.0      4
# 300.0      7
# 350.0      1
# 360.0    311
# 480.0      8
# dtype: int64

# %%
import seaborn as sns
sns.countplot(df['Loan_Amount_Term'],label="Count")
plt.show()

# %%
print(df.groupby('Credit_History').size())
# Out:
# Credit_History
# 0.0     59
# 1.0    279
# dtype: int64

# %%
import seaborn as sns
sns.countplot(df['Credit_History'],label="Count")
plt.show()

# %%
import matplotlib.pyplot as plt
labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
sizes = [15, 30, 45, 10]
explode = (0, 0.1, 0, 0)
fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',shadow=True, startangle=90)
ax1.axis('equal')  
plt.show()

# %%
df["LoanAmount"].mean()
# Out:
# 136.13259668508286

# %%
df["CoapplicantIncome"].mean()
# Out:
# 1569.5776566757493

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("train.csv")
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# 6    LP001013    Male     Yes          0  Not Graduate            No
# 7    LP001014    Male     Yes         3+      Graduate            No
# 8    LP001018    Male     Yes          2      Graduate            No
# 9    LP001020    Male     Yes          1      Graduate            No
# 10   LP001024    Male     Yes          2      Graduate            No
# 11   LP001027    Male     Yes          2      Graduate           NaN
# 12   LP001028    Male     Yes          2      Graduate            No
# ...

# %%
print(df.groupby('Loan_Status').size())
# Out:
# Loan_Status
# N    192
# Y    422
# dtype: int64

# %%
import seaborn as sns
sns.countplot(df['Loan_Status'],label="Count")
plt.show()

# %%
result = pd.merge(train, test, how='train', on=["Loan_ID", "Loan_ID"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-7a7576cd43c2> in <module>()
# ----> 1 result = pd.merge(train, test, how='train', on=["Loan_ID", "Loan_ID"])
#
# NameError: name 'train' is not defined

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
train = pd.read_csv("train.csv")
train
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# 6    LP001013    Male     Yes          0  Not Graduate            No
# 7    LP001014    Male     Yes         3+      Graduate            No
# 8    LP001018    Male     Yes          2      Graduate            No
# 9    LP001020    Male     Yes          1      Graduate            No
# 10   LP001024    Male     Yes          2      Graduate            No
# 11   LP001027    Male     Yes          2      Graduate           NaN
# 12   LP001028    Male     Yes          2      Graduate            No
# ...

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
test = pd.read_csv("train.csv")
test
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# 6    LP001013    Male     Yes          0  Not Graduate            No
# 7    LP001014    Male     Yes         3+      Graduate            No
# 8    LP001018    Male     Yes          2      Graduate            No
# 9    LP001020    Male     Yes          1      Graduate            No
# 10   LP001024    Male     Yes          2      Graduate            No
# 11   LP001027    Male     Yes          2      Graduate           NaN
# 12   LP001028    Male     Yes          2      Graduate            No
# ...

# %%
result = pd.merge(train, test, how='train', on=["Loan_ID"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-e74ebe19249d> in <module>()
# ----> 1 result = pd.merge(train, test, how='train', on=["Loan_ID"])
#
# ~/Downloads/yes/lib/python3.6/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      59                          copy=copy, indicator=indicator,
#      60                          validate=validate)
# ---> 61     return op.get_result()
#      62
#      63
#
# ~/Downloads/yes/lib/python3.6/site-packages/pandas/core/reshape/merge.py in get_result(self)
#     565                 self.left, self.right)
#     566
# --> 567         join_index, left_indexer, right_indexer = self._get_join_info()
#     568
#     569         ldata, rdata = self.left._data, self.right._data
#
# ...

# %%
import pandas as pd

    a = pd.read_csv("train.csv", names = ["Loan_ID", "Loan_Status"],header = 0).astype(basestring)

    b = pd.read_csv("test.csv").astype(basestring)

    merged= a.merge(b, on='Loan_ID',how='outer')

    merged.to_csv("test.csv", index=False)
# Out:
#   File "<ipython-input-39-2dfed0699815>", line 5
#     b = pd.read_csv("test.csv").astype(basestring)
#     ^
# IndentationError: unexpected indent

# %%
print(df['Loan_ID'].unique())
# Out:
# ['LP001002' 'LP001003' 'LP001005' 'LP001006' 'LP001008' 'LP001011'
#  'LP001013' 'LP001014' 'LP001018' 'LP001020' 'LP001024' 'LP001027'
#  'LP001028' 'LP001029' 'LP001030' 'LP001032' 'LP001034' 'LP001036'
#  'LP001038' 'LP001041' 'LP001043' 'LP001046' 'LP001047' 'LP001050'
#  'LP001052' 'LP001066' 'LP001068' 'LP001073' 'LP001086' 'LP001087'
#  'LP001091' 'LP001095' 'LP001097' 'LP001098' 'LP001100' 'LP001106'
#  'LP001109' 'LP001112' 'LP001114' 'LP001116' 'LP001119' 'LP001120'
#  'LP001123' 'LP001131' 'LP001136' 'LP001137' 'LP001138' 'LP001144'
#  'LP001146' 'LP001151' 'LP001155' 'LP001157' 'LP001164' 'LP001179'
#  'LP001186' 'LP001194' 'LP001195' 'LP001197' 'LP001198' 'LP001199'
#  'LP001205' 'LP001206' 'LP001207' 'LP001213' 'LP001222' 'LP001225'
#  'LP001228' 'LP001233' 'LP001238' 'LP001241' 'LP001243' 'LP001245'
#  'LP001248' 'LP001250' 'LP001253' 'LP001255' 'LP001256' 'LP001259'
#  'LP001263' 'LP001264' 'LP001265' 'LP001266' 'LP001267' 'LP001273'
# ...

# %%
print(test['Loan_ID'].unique())
# Out:
# ['LP001002' 'LP001003' 'LP001005' 'LP001006' 'LP001008' 'LP001011'
#  'LP001013' 'LP001014' 'LP001018' 'LP001020' 'LP001024' 'LP001027'
#  'LP001028' 'LP001029' 'LP001030' 'LP001032' 'LP001034' 'LP001036'
#  'LP001038' 'LP001041' 'LP001043' 'LP001046' 'LP001047' 'LP001050'
#  'LP001052' 'LP001066' 'LP001068' 'LP001073' 'LP001086' 'LP001087'
#  'LP001091' 'LP001095' 'LP001097' 'LP001098' 'LP001100' 'LP001106'
#  'LP001109' 'LP001112' 'LP001114' 'LP001116' 'LP001119' 'LP001120'
#  'LP001123' 'LP001131' 'LP001136' 'LP001137' 'LP001138' 'LP001144'
#  'LP001146' 'LP001151' 'LP001155' 'LP001157' 'LP001164' 'LP001179'
#  'LP001186' 'LP001194' 'LP001195' 'LP001197' 'LP001198' 'LP001199'
#  'LP001205' 'LP001206' 'LP001207' 'LP001213' 'LP001222' 'LP001225'
#  'LP001228' 'LP001233' 'LP001238' 'LP001241' 'LP001243' 'LP001245'
#  'LP001248' 'LP001250' 'LP001253' 'LP001255' 'LP001256' 'LP001259'
#  'LP001263' 'LP001264' 'LP001265' 'LP001266' 'LP001267' 'LP001273'
# ...

# %%
print(train['Loan_ID'].unique())
# Out:
# ['LP001002' 'LP001003' 'LP001005' 'LP001006' 'LP001008' 'LP001011'
#  'LP001013' 'LP001014' 'LP001018' 'LP001020' 'LP001024' 'LP001027'
#  'LP001028' 'LP001029' 'LP001030' 'LP001032' 'LP001034' 'LP001036'
#  'LP001038' 'LP001041' 'LP001043' 'LP001046' 'LP001047' 'LP001050'
#  'LP001052' 'LP001066' 'LP001068' 'LP001073' 'LP001086' 'LP001087'
#  'LP001091' 'LP001095' 'LP001097' 'LP001098' 'LP001100' 'LP001106'
#  'LP001109' 'LP001112' 'LP001114' 'LP001116' 'LP001119' 'LP001120'
#  'LP001123' 'LP001131' 'LP001136' 'LP001137' 'LP001138' 'LP001144'
#  'LP001146' 'LP001151' 'LP001155' 'LP001157' 'LP001164' 'LP001179'
#  'LP001186' 'LP001194' 'LP001195' 'LP001197' 'LP001198' 'LP001199'
#  'LP001205' 'LP001206' 'LP001207' 'LP001213' 'LP001222' 'LP001225'
#  'LP001228' 'LP001233' 'LP001238' 'LP001241' 'LP001243' 'LP001245'
#  'LP001248' 'LP001250' 'LP001253' 'LP001255' 'LP001256' 'LP001259'
#  'LP001263' 'LP001264' 'LP001265' 'LP001266' 'LP001267' 'LP001273'
# ...

# %%
import requests
url = "http://www.wikipedia.org"
r = requests.get(url)
text = r.text

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
import plotly.offline as py
py.init_notebook_mode(connected=True)
from sklearn.ensemble import RandomForestClassifier

# Data import
attrition = pd.read_csv('C:/Users/monik/Desktop/DA/final_project/excel_txt/vstupy/att_csv.csv')
attrition.head()
attritionnum = pd.read_csv('C:/Users/monik/Desktop/DA/final_project/excel_txt/vstupy/att_num_csv.csv')
attritionnum.head()

# Dataframe definition
df = pd.DataFrame(data=attritionnum, columns = ['employee_number', 'age', 
        'business_travel_num', 'monhtly_income', 	'department_num', 	'distance_home',
        'education', 'edu_field_num', 'environment_satisfation', 'gender_num', 'job_involvement',
       'job_level',	'job_role_num', 'job_satisfaction', 'marital_status_num', 'num_comp_worked',
       'overtime_num', 'percent_salary_hike', 'performance_rating', 'relationship_satisfaction', 
       'stock_option_level',	'total_working_years', 'training_times_last_y', 'work_life_balance', 
       'years_at_company', 'years_in_current_role', 'years_since_last_promo', 'years_with_curr_manager',
       'attrition_num'])  
df.head()

# Generating a random # between 1 and 0, if # <= 0.75 the observations goes to the group train
df['is_train'] = np.random.uniform(0, 1, len(df)) <= .75
df.head()

# Delete employee number - not needed, could mess the method
del df['employee_number']
df.head()

# Create two new dataframes, one with the training rows, one with the test rows
train, test = df[df['is_train']==True], df[df['is_train']==False]

# Show the number of observations for the test and training dataframes
print('Number of observations in the training data:', len(train))
print('Number of observations in the test data:',len(test))

# Create a list of the feature column's names - without 29th column attrition
features = df.columns[:27]

# Defining the variable to be predicted - the target
x_train = train
y_train = train['attrition_num']
train.head()

# Defining test
x_test = test
y_test = test['attrition_num']

# Create a random forest Classifier
clf = RandomForestClassifier(n_estimators=25, n_jobs=2, random_state=0)

# Train the Classifier to take the training features and learn how they relate to the training y (attrition_num)
clf.fit(train[features], y_train)

# Apply the Classifier we trained to the test data
clf.predict(test[features])

# View the predicted probabilities of the first 10 observations
clf.predict_proba(test[features])[0:10]
preds = clf.predict(test[features])

# Create confusion matrix, WHICH REALLY IS CONFUSING AT FIRST
pd.crosstab(test['attrition_num'], preds, rownames=['Actual Attrition'], colnames=['Predicted Attrition'])

# View a list of the features and their importance scores
list(zip(train[features], clf.feature_importances_))

# The accuracy_score function computes the accuracy, either the fraction (default) or the count (normalize=False) of
#correct predictions.
score = accuracy_score(y_test, preds)
score_count = accuracy_score(y_test, preds, normalize=False)
print(score)
print(score_count)

# Scatter plot
y = ['age', 'business_travel_num', 'monthly_income', 'department_num', 'distance_home',
     'education', 'edu_field_num', 'environment_satisfation', 'gender_num',
     'job_involvement', 'job_level', 'job_role_num', 'job_satisfaction',
    'marital_status_num', 'num_comp_worked', 'overtime_num', 'percent_salary_hike',
    'performance_rating', 'relationship_satisfaction', 'stock_option_level', 
    'total_working_years', 'training_times_last_y', 'work_life_balance', 
    'years_at_company', 'years_in_current_role',     'years_since_last_promo',
    'years_with_curr_manager']
x = clf.feature_importances_
plt.figure(figsize=(15, 10))
plt.scatter(x, y, c=x, vmin=0, vmax=0.10, s=400, alpha = 0.75, cmap='plasma')
plt.colorbar()
#plt.ylabel('Attributes')
plt.xlabel('Feature Importance', fontsize=15)
plt.yticks([])
#plt.xticks(rotation=90)
plt.title('Random Forest Feature Importance', fontsize=18)
labels = ['age', 'business travel', 'monthly income', 'department', 'distance from home', 'education level', 
          'education field', 'environment satisfation', 'gender', 'job involvement', 'job level', 'job role', 
          'job satisfaction', 'marital status', 'number companies worked', 'overtime', 'percent salary hike', 
          'performance rating', 'relationship satisfaction', 'stock option level', 'total working years', 
          'training times last year', 'work life balance', 'years at company', 'years in current role',
          'years since last promotion', 'years with current manager']
for label, x, y in zip(labels, x, y):
    plt.annotate(
        label,
        xy=(x, y), xytext=(-20, 20),
        textcoords='offset points', ha='left', va='top',
        bbox=dict(boxstyle='round,pad=0.5', fc='white', alpha=0.5),
        arrowprops=dict(arrowstyle = '->', connectionstyle='arc3,rad=0'))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-72e88c6a95bc> in <module>()
#       3 import matplotlib.pyplot as plt
#       4 from sklearn.metrics import accuracy_score
# ----> 5 import plotly.offline as py
#       6 py.init_notebook_mode(connected=True)
#       7 from sklearn.ensemble import RandomForestClassifier
#
# ModuleNotFoundError: No module named 'plotly'

# %%
from sklearn.datasets import load_iris
import numpy as np
from sklearn import tree

# Prints the name of iris species from the predicted number
def decode(num):
	for i in num:
		if i==0:
			print("setosa")
		elif i==1:
			print("versicolor")
		else:
			print("virginica")
#----------------------------------------------------------

iris = load_iris()
test_ids = []

for i in range (0, 20):
	test_ids.append(i)
for i in range (50, 70):
	test_ids.append(i)
for i in range (100, 120):
	test_ids.append(i)

# Training data
train_data = np.delete(iris.data, test_ids, axis=0)
train_target = np.delete(iris.target, test_ids)

clf = tree.DecisionTreeClassifier()
clf.fit(train_data, train_target)

d1 = float(input("Enter sepal length : "))
d2 = float(input("Enter sepal width : "))
d3 = float(input("Enter petal length : "))
d4 = float(input("Enter petal width : "))

data = [d1, d2, d3, d4]

decode(clf.predict(data))
# Out:
# Enter sepal length : 10
# Enter sepal width : 10
# Enter petal length : 10
# Enter petal width : 20
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-b3b70838aedb> in <module>()
#      38 data = [d1, d2, d3, d4]
#      39
# ---> 40 decode(clf.predict(data))
#
# ~/Downloads/yes/lib/python3.6/site-packages/sklearn/tree/tree.py in predict(self, X, check_input)
#     410         """
#     411         check_is_fitted(self, 'tree_')
# --> 412         X = self._validate_X_predict(X, check_input)
#     413         proba = self.tree_.predict(X)
#     414         n_samples = X.shape[0]
#
# ~/Downloads/yes/lib/python3.6/site-packages/sklearn/tree/tree.py in _validate_X_predict(self, X, check_input)
#     371         """Validate X whenever one tries to predict, apply, predict_proba"""
#     372         if check_input:
# ...

# %%
from scipy.spatial import distance
def eu(a, b):
	return distance.euclidean(a, b)

class KNN:
	def fit(self, x_train, y_train):
		self.x_train = x_train
		self.y_train = y_train
	
	def predict(self, x_test):
		predictions = []
		for row in x_test:
			label = self.closest(row)
			predictions.append(label)
		return predictions

	def closest(self, row):
		best_dist = eu(row, self.x_train[0])
		best_index = 0
		for i in range (1, len(self.x_train)):
			dist = eu(row, self.x_train[i])
			if dist < best_dist:
				best_dist = dist
				best_index = i
		return self.y_train[best_index]

from sklearn.datasets import load_iris
iris = load_iris()
x = iris.data
y = iris.target

from sklearn.cross_validation import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)

clf = KNN()
clf.fit(x_train, y_train)
prediction = clf.predict(x_test)

from sklearn.metrics import accuracy_score as acs
print(acs(prediction, y_test))
# Out:
# /home/sanjeet/Downloads/yes/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# 0.9333333333333333

# %%
import pandas as pd

# %%
data = pd.read_csv("turnover.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-6f0b97fdb161> in <module>()
# ----> 1 data = pd.read_csv("turnover.csv")
#
# ~/Downloads/yes/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
# ...

# %%
data = pd.read_csv("turnover.xlsx")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-7b69e052e655> in <module>()
# ----> 1 data = pd.read_csv("turnover.xlsx")
#
# ~/Downloads/yes/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
# ...

# %%
pwd
# Out:
# '/home/sanjeet'

# %%
cd /home/sanjeet/Downloads
# Out:
# /home/sanjeet/Downloads

# %%
data = pd.read_excel("turnover.xlsx")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-9-7b69e052e655> in <module>()
# ----> 1 data = pd.read_csv("turnover.xlsx")
#
# ~/Downloads/yes/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
# ...

# %%
data = pd.read_excel("turnover.xlsx")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
# Age                         1470 non-null int64
# Attrition                   1470 non-null object
# BusinessTravel              1470 non-null object
# DailyRate                   1470 non-null int64
# Department                  1470 non-null object
# DistanceFromHome            1470 non-null int64
# Education                   1470 non-null int64
# EducationField              1470 non-null object
# EmployeeCount               1470 non-null int64
# EmployeeNumber              1470 non-null int64
# EnvironmentSatisfaction     1470 non-null int64
# Gender                      1470 non-null object
# HourlyRate                  1470 non-null int64
# JobInvolvement              1470 non-null int64
# JobLevel                    1470 non-null int64
# JobRole                     1470 non-null object
# JobSatisfaction             1470 non-null int64
# ...

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#            ...           RelationshipSatisfaction StandardHours  \
# ...

# %%
print(salary.data.unique())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-8dc5f1476ba9> in <module>()
# ----> 1 print(salary.data.unique())
#
# NameError: name 'salary' is not defined

# %%
data.BusinessTravel = data.BusinessTravel.astype('category')
data.BusinessTravel = data.BusinessTravel.cat.reorder_categories('Travel_Rarely','Travel_Frequently')
data.BusinessTravel = data.BusinessTravel.cat.codes
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-9c4fc8de2d43> in <module>()
#       1 data.BusinessTravel = data.BusinessTravel.astype('category')
# ----> 2 data.BusinessTravel = data.BusinessTravel.cat.reorder_categories('Travel_Rarely','Travel_Frequently')
#       3 data.BusinessTravel = data.BusinessTravel.cat.codes
#
# ~/Downloads/yes/lib/python3.6/site-packages/pandas/core/accessor.py in f(self, *args, **kwargs)
#      86
#      87             def f(self, *args, **kwargs):
# ---> 88                 return self._delegate_method(name, *args, **kwargs)
#      89
#      90             f.__name__ = name
#
# ~/Downloads/yes/lib/python3.6/site-packages/pandas/core/arrays/categorical.py in _delegate_method(self, name, *args, **kwargs)
#    2401         from pandas import Series
#    2402         method = getattr(self.categorical, name)
# ...

# %%
print(BusunessTravel.data.unique())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-7e589c00b6e1> in <module>()
# ----> 1 print(BusunessTravel.data.unique())
#
# NameError: name 'BusunessTravel' is not defined

# %%
print(BusinessTravel.data.unique())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-eb1c359e468c> in <module>()
# ----> 1 print(BusinessTravel.data.unique())
#
# NameError: name 'BusinessTravel' is not defined

# %%
import seaborn as sns
sns.countplot(data['BusinessTravel'],label="Count")
plt.show()

# %%
data.BusinessTravel = data.BusinessTravel.astype('category')
data.BusinessTravel = data.BusinessTravel.cat.reorder_categories('Non-Travel','Travel_Rarely','Travel_Frequently')
data.BusinessTravel = data.BusinessTravel.cat.codes
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-6ee2ed1deaa1> in <module>()
#       1 data.BusinessTravel = data.BusinessTravel.astype('category')
# ----> 2 data.BusinessTravel = data.BusinessTravel.cat.reorder_categories('Non-Travel','Travel_Rarely','Travel_Frequently')
#       3 data.BusinessTravel = data.BusinessTravel.cat.codes
#
# ~/Downloads/yes/lib/python3.6/site-packages/pandas/core/accessor.py in f(self, *args, **kwargs)
#      86
#      87             def f(self, *args, **kwargs):
# ---> 88                 return self._delegate_method(name, *args, **kwargs)
#      89
#      90             f.__name__ = name
#
# ~/Downloads/yes/lib/python3.6/site-packages/pandas/core/arrays/categorical.py in _delegate_method(self, name, *args, **kwargs)
#    2401         from pandas import Series
#    2402         method = getattr(self.categorical, name)
# ...

# %%
import seaborn as sns
sns.countplot(data['Department'],label="Count")
plt.show()

# %%
data
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# 5      32        No  Travel_Frequently       1005  Research & Development
# 6      59        No      Travel_Rarely       1324  Research & Development
# 7      30        No      Travel_Rarely       1358  Research & Development
# 8      38        No  Travel_Frequently        216  Research & Development
# 9      36        No      Travel_Rarely       1299  Research & Development
# 10     35        No      Travel_Rarely        809  Research & Development
# 11     29        No      Travel_Rarely        153  Research & Development
# ...

# %%
import seaborn as sns
sns.countplot(data['Age'],label="Count")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-69d156609124> in <module>()
#       1 import seaborn as sns
# ----> 2 sns.countplot(data['Age'/10],label="Count")
#       3 plt.show()
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
import seaborn as sns
sns.countplot(data['YearsWithCurrManager'],label="Count")
plt.show()

# %%
import seaborn as sns
sns.countplot(data['YearsWithCurrManager'],data['Department'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-e349fc109c73> in <module>()
#       1 import seaborn as sns
# ----> 2 sns.countplot(data['YearsWithCurrManager'],data['Department'])
#       3 plt.show()
#
# ~/Downloads/yes/lib/python3.6/site-packages/seaborn/categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3350         y = x
#    3351     elif x is not None and y is not None:
# -> 3352         raise TypeError("Cannot pass values for both `x` and `y`")
#    3353     else:
#    3354         raise TypeError("Must pass values for either `x` or `y`")
#
# TypeError: Cannot pass values for both `x` and `y`

# %%
import seaborn as sns
sns.countplot(data['StandardHours'],data['Department'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-ef7408065ce5> in <module>()
#       1 import seaborn as sns
# ----> 2 sns.countplot(data['StandardHours'],data['Department'])
#       3 plt.show()
#
# ~/Downloads/yes/lib/python3.6/site-packages/seaborn/categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3350         y = x
#    3351     elif x is not None and y is not None:
# -> 3352         raise TypeError("Cannot pass values for both `x` and `y`")
#    3353     else:
#    3354         raise TypeError("Must pass values for either `x` or `y`")
#
# TypeError: Cannot pass values for both `x` and `y`

# %%
import seaborn as sns
sns.countplot(data['YearsWithCurrManager'],label = 'count')
plt.show()

# %%
import seaborn as sns
sns.countplot(data['StandardHours'],label = 'count')
plt.show()

# %%
data
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# 5      32        No  Travel_Frequently       1005  Research & Development
# 6      59        No      Travel_Rarely       1324  Research & Development
# 7      30        No      Travel_Rarely       1358  Research & Development
# 8      38        No  Travel_Frequently        216  Research & Development
# 9      36        No      Travel_Rarely       1299  Research & Development
# 10     35        No      Travel_Rarely        809  Research & Development
# 11     29        No      Travel_Rarely        153  Research & Development
# ...

# %%
import seaborn as sns
sns.countplot(data['EducationField'],label = 'count')
plt.show()
